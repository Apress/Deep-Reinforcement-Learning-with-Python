# %% [markdown]
# # Robotics Environment

# %% [markdown]
# #### Install MuJoCo
#
# 1. Download the MuJoCo version 2.1 binaries for
#    [Linux](https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz) or
#    [OSX](https://mujoco.org/download/mujoco210-macos-x86_64.tar.gz).
# 2. Extract the downloaded `mujoco210` directory into `~/.mujoco/mujoco210`.
#
# You can read more about it [here](https://github.com/openai/mujoco-py/blob/master/README.md)
#
#
# Please add following line to `.bashrc`:
# `export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/nsanghi/.mujoco/mujoco210/bin`
#
# If you get error - you may need to run following commands:
#
#
# `sudo apt-get install libosmesa6-dev`
#
# `sudo apt-get install patchelf`
#
# ### Note for Macbook with arm 64 architecture chipsets (m1/m2/m3 chipsets) trying to run this notebook directly on a local install
# As of writing the book, Mujoco is not supported for your architecture.
# If you are still interested to pursue that route you may want to take a look at a github thread for more guidance:
# https://github.com/google-deepmind/mujoco/issues/882
#
# The other option is to use Rosetta on your Mac and then remove/install Homebrew for the intel architecture. After these steps, you should be able to install mujoco
#
# **Having said that, easier and safer option would be to use VSCode devcontainer setup. Please refer to the the `istallation_step.pdf` in root directory for more details.**

# %% [markdown]
# #### Running in Colab/Kaggle
#
# If you are running this on Colab, please uncomment below cells and run this to install required dependencies.
#
# **Please note that this notebook requires additonal installation as explained above. Please follow the additional install process making tweaks, if necessary, as per restrictions in your cloud environment**

# %%
## uncomment and execute this cell to install all the the dependencies if running in Google Colab or Kaggle
# !apt-get update 
# !apt-get install -y swig cmake ffmpeg freeglut3-dev xvfb

# %%
## Uncomment and execute this cell to install all the the dependencies if running in Google Colab or Kaggle

## Uncomment and run for Colab
# !git clone https://github.com/nsanghi/drl-2ed
# %cd /content/drl-2ed 
# !pip install  -r requirements.txt
# %cd chapter6


## Uncomment and run for Kaggle
# !git clone https://github.com/nsanghi/drl-2ed
# %cd /kaggle/working/drl-2ed 
# !pip install  -r requirements.txt
# %cd chapter6

# %%
## Uncomment and Rerun the cd command in case you were asked to restart the kernel and you followed that message
## as after resart the kernel will again point back to root folder


## Uncomment and run for Colab
# %cd /content/drl-2ed 
# %cd chapter6


## Uncomment and run for Kaggle
# %cd /kaggle/working/drl-2ed 
# %cd chapter6

# %% [markdown]
# ### Imports

# %%
from base64 import b64encode
from IPython.display import HTML
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv


def play_video(file_path):
    mp4 = open(file_path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML("""
        <video width=400 controls>
              <source src="%s" type="video/mp4">
        </video>
        """ % data_url)
# Out:
# 2023-11-05 23:05:00.498122: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-05 23:05:00.500980: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-05 23:05:00.535813: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-05 23:05:00.535851: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-05 23:05:00.535869: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-05 23:05:00.542517: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-05 23:05:00.542922: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-05 23:05:01.731125: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# #### Login to Weights and Biases

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: nsanghi. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# **IMPORTANT**
# In case you face a login error with `wandb.login()`, please run the following cell by setting first your wandb api key

# %%
import os
os.environ["WANDB_API_KEY"] = "Your WANDB_API_KEY......"
import wandb
wandb.login()

# %% [markdown]
# ```{python}
# hyperparams = {
#     "Reacher-v4": dict(
#         normalize=False,
#         n_envs=1,
#         policy="MlpPolicy",
#         n_timesteps=100000.0,
#         batch_size=32,
#         n_steps=512,
#         gamma=0.9,
#         learning_rate=0.000104019,
#         ent_coef=7.52585e-08,
#         clip_range=0.3,
#         n_epochs=5,
#         gae_lambda=1.0,
#         max_grad_norm=0.9,
#         vf_coef=0.950368
#     )
# }
# ```

# %% [markdown]
# #### Train Reacher MuJoCo using RL Zoo3

# %%
# !python -m rl_zoo3.train --algo ppo --env Reacher-v4 --progress \
--log-interval 400 --save-freq 10000 --eval-freq 10000 --eval-episodes 10 \
--n-timesteps 100000 --conf-file ppo_config_6e.py \
--track --wandb-project-name ppo-reacher-v4 -f logs/6_d/rlzoo3/
# Out:
# 2023-11-06 01:17:16.432035: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-06 01:17:16.434352: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 01:17:16.469920: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-06 01:17:16.470017: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-06 01:17:16.470041: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-06 01:17:16.477040: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 01:17:16.477331: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-06 01:17:17.296151: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ========== Reacher-v4 ==========
# Seed: 2709960376
# wandb: Currently logged in as: nsanghi. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in /home/nsanghi/sandbox/apress/drl-2ed/chapter6/wandb/run-20231106_011721-isjrthv7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Reacher-v4__ppo__2709960376__1699213640
# wandb: ⭐️ View project at https://wandb.ai/nsanghi/ppo-reacher-v4
# wandb: 🚀 View run at https://wandb.ai/nsanghi/ppo-reacher-v4/runs/isjrthv7
# Loading hyperparameters from: ppo_config_6e.py
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('clip_range', 0.3),
#              ('ent_coef', 7.52585e-08),
#              ('gae_lambda', 1.0),
#              ('gamma', 0.9),
#              ('learning_rate', 0.000104019),
#              ('max_grad_norm', 0.9),
#              ('n_envs', 1),
#              ('n_epochs', 5),
#              ('n_steps', 512),
#              ('n_timesteps', 100000.0),
#              ('normalize', False),
#              ('policy', 'MlpPolicy'),
#              ('vf_coef', 0.950368)])
# Using 1 environments
# Overwriting n_timesteps with n=100000
# Creating test environment
# Using cpu device
# Log path: logs/6_e/rlzoo3//ppo/Reacher-v4_1
# Logging to runs/Reacher-v4__ppo__2709960376__1699213640/Reacher-v4/PPO_1
# Eval num_timesteps=10000, episode_reward=-13.02 +/- 4.20━━━━━━━━ 9,887/100,000  [ 0:00:14 < 0:02:12 , 687 it/s ]
# Episode length: 50.00 +/- 0.000m━━━━━━━━━━━━━━━━━━━━━━━ 9,887/100,000  [ 0:00:14 < 0:02:12 , 687 it/s ]
# -----------------------------------------━━━━━━━━━━━━━━━━━━━ 9,887/100,000  [ 0:00:14 < 0:02:12 , 687 it/s ]
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | -13         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.001352274 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | -0.637      |
# |    learning_rate        | 0.000104    |
# |    loss                 | 21.8        |
# |    n_updates            | 95          |
# |    policy_gradient_loss | -0.00284    |
# |    std                  | 0.951       |
# |    value_loss           | 30.2        |
# -----------------------------------------
# New best mean reward!m╸━━━━━━━━━━━━━━━━━━━━━━━ 9,887/100,000  [ 0:00:14 < 0:02:12 , 687 it/s ]
# Eval num_timesteps=20000, episode_reward=-9.84 +/- 3.16━━━━━━━━ 19,969/100,000  [ 0:00:30 < 0:02:03 , 652 it/s ]
# Episode length: 50.00 +/- 0.00━━━━━━━━━━━━━━━━━━━━ 19,969/100,000  [ 0:00:30 < 0:02:03 , 652 it/s ]
# ------------------------------------------━━━━━━━━━━━━━━━━━ 19,969/100,000  [ 0:00:30 < 0:02:03 , 652 it/s ]
# | eval/                   |              |
# |    mean_ep_length       | 50           |
# |    mean_reward          | -9.84        |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0011662848 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | -0.279       |
# |    learning_rate        | 0.000104     |
# |    loss                 | 1.5          |
# |    n_updates            | 195          |
# |    policy_gradient_loss | -0.00367     |
# |    std                  | 0.828        |
# |    value_loss           | 2.21         |
# ------------------------------------------
# New best mean reward!╸━━━━━━━━━━━━━━━━━━━━ 19,969/100,000  [ 0:00:30 < 0:02:03 , 652 it/s ]
# Eval num_timesteps=30000, episode_reward=-10.50 +/- 2.18━━━━━━━ 29,853/100,000  [ 0:00:45 < 0:01:52 , 630 it/s ]
# Episode length: 50.00 +/- 0.000m╺━━━━━━━━━━━━━━━━━ 29,853/100,000  [ 0:00:45 < 0:01:52 , 630 it/s ]
# -----------------------------------------m━━━━━━━━━━━━━━━━━ 29,853/100,000  [ 0:00:45 < 0:01:52 , 630 it/s ]
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | -10.5       |
# | time/                   |             |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.002034219 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.000104    |
# |    loss                 | 1.1         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0045     |
# |    std                  | 0.723       |
# |    value_loss           | 1.24        |
# -----------------------------------------
# Eval num_timesteps=40000, episode_reward=-9.38 +/- 2.51━━━━━━━━ 39,928/100,000  [ 0:01:00 < 0:01:31 , 667 it/s ]
# Episode length: 50.00 +/- 0.00╸━━━━━━━━━━━━━━━ 39,928/100,000  [ 0:01:00 < 0:01:31 , 667 it/s ]
# ------------------------------------------0m━━━━━━━━━━━━━━━ 39,928/100,000  [ 0:01:00 < 0:01:31 , 667 it/s ]
# | eval/                   |              |
# |    mean_ep_length       | 50           |
# |    mean_reward          | -9.38        |
# | time/                   |              |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 0.0018890968 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.042        |
# |    learning_rate        | 0.000104     |
# |    loss                 | 1.55         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00486     |
# |    std                  | 0.633        |
# |    value_loss           | 1.6          |
# ------------------------------------------
# New best mean reward!━━━━╸━━━━━━━━━━━━━━━ 39,928/100,000  [ 0:01:00 < 0:01:31 , 667 it/s ]
# Eval num_timesteps=50000, episode_reward=-8.77 +/- 3.02━━━━━━━━ 49,982/100,000  [ 0:01:15 < 0:01:14 , 682 it/s ]
# Episode length: 50.00 +/- 0.000m╺━━━━━━━━━━━━ 49,982/100,000  [ 0:01:15 < 0:01:14 , 682 it/s ]
# ------------------------------------------━━━━━━━━━━━━ 49,982/100,000  [ 0:01:15 < 0:01:14 , 682 it/s ]
# | eval/                   |              |
# |    mean_ep_length       | 50           |
# |    mean_reward          | -8.77        |
# | time/                   |              |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0033457302 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.000104     |
# |    loss                 | 0.871        |
# |    n_updates            | 485          |
# |    policy_gradient_loss | -0.00692     |
# |    std                  | 0.558        |
# |    value_loss           | 0.944        |
# ------------------------------------------
# New best mean reward!━━━━━━━╺━━━━━━━━━━━━ 49,982/100,000  [ 0:01:15 < 0:01:14 , 682 it/s ]
# Eval num_timesteps=60000, episode_reward=-9.25 +/- 2.69━━━━━━━━ 59,955/100,000  [ 0:01:33 < 0:01:06 , 607 it/s ]
# Episode length: 50.00 +/- 0.00╸━━━━━━━━━━ 59,955/100,000  [ 0:01:33 < 0:01:06 , 607 it/s ]
# -----------------------------------------━━━━━━━━━━ 59,955/100,000  [ 0:01:33 < 0:01:06 , 607 it/s ]
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | -9.25       |
# | time/                   |             |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.001877877 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0387      |
# |    learning_rate        | 0.000104    |
# |    loss                 | 0.29        |
# |    n_updates            | 585         |
# |    policy_gradient_loss | -0.00592    |
# |    std                  | 0.489       |
# |    value_loss           | 0.743       |
# -----------------------------------------
# Eval num_timesteps=70000, episode_reward=-10.76 +/- 3.10━━━━━━━ 69,949/100,000  [ 0:01:52 < 0:00:56 , 544 it/s ]
# Episode length: 50.00 +/- 0.00━━━╺━━━━━━━ 69,949/100,000  [ 0:01:52 < 0:00:56 , 544 it/s ]
# ------------------------------------------╺━━━━━━━ 69,949/100,000  [ 0:01:52 < 0:00:56 , 544 it/s ]
# | eval/                   |              |
# |    mean_ep_length       | 50           |
# |    mean_reward          | -10.8        |
# | time/                   |              |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.0066577806 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.000104     |
# |    loss                 | 0.342        |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.0057      |
# |    std                  | 0.43         |
# |    value_loss           | 0.563        |
# ------------------------------------------
# Eval num_timesteps=80000, episode_reward=-12.55 +/- 1.560m━━━━━ 79,891/100,000  [ 0:02:07 < 0:00:33 , 626 it/s ]
# Episode length: 50.00 +/- 0.00━━━━━╸━━━━━ 79,891/100,000  [ 0:02:07 < 0:00:33 , 626 it/s ]
# -----------------------------------------91m╸━━━━━ 79,891/100,000  [ 0:02:07 < 0:00:33 , 626 it/s ]
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | -12.5       |
# | time/                   |             |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.013218039 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.000104    |
# |    loss                 | 0.328       |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00867    |
# |    std                  | 0.377       |
# |    value_loss           | 0.463       |
# -----------------------------------------
# Eval num_timesteps=90000, episode_reward=-8.62 +/- 3.77m━━ 89,910/100,000  [ 0:02:23 < 0:00:16 , 662 it/s ]
# Episode length: 50.00 +/- 0.00━━━━━━━━╺━━ 89,910/100,000  [ 0:02:23 < 0:00:16 , 662 it/s ]
# -----------------------------------------m╺━━ 89,910/100,000  [ 0:02:23 < 0:00:16 , 662 it/s ]
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | -8.62       |
# | time/                   |             |
# |    total_timesteps      | 90000       |
# | train/                  |             |
# |    approx_kl            | 0.010185342 |
# |    clip_fraction        | 0.00977     |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.000104    |
# |    loss                 | 0.231       |
# |    n_updates            | 875         |
# |    policy_gradient_loss | -0.00847    |
# |    std                  | 0.334       |
# |    value_loss           | 0.345       |
# -----------------------------------------
# New best mean reward!━━━━━━━━━━━━━━━━━╺━━ 89,910/100,000  [ 0:02:23 < 0:00:16 , 662 it/s ]
# Eval num_timesteps=100000, episode_reward=-8.73 +/- 2.240m 99,997/100,000  [ 0:02:38 < 0:00:01 , 643 it/s ]t/s ]
# Episode length: 50.00 +/- 0.00━━━━━━━━━━╸ 99,997/100,000  [ 0:02:38 < 0:00:01 , 643 it/s ]
# -----------------------------------------╸ 99,997/100,000  [ 0:02:38 < 0:00:01 , 643 it/s ]
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | -8.73       |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.010235589 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.0995      |
# |    learning_rate        | 0.000104    |
# |    loss                 | 0.261       |
# |    n_updates            | 975         |
# |    policy_gradient_loss | -0.00694    |
# |    std                  | 0.298       |
# |    value_loss           | 0.372       |
# -----------------------------------------
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━ 100,352/100,000  [ 0:02:38 < 0:00:00 , 638 it/s ]t/s ]
# Saving to logs/6_e/rlzoo3//ppo/Reacher-v4_1

# %% [markdown]
# #### Evaluate trained agent

# %%
# !python -m rl_zoo3.enjoy --algo ppo --env Reacher-v4 --no-render --n-timesteps 5000 --folder logs/6_d/rlzoo3
# Out:
# 2023-11-06 00:16:24.073646: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-06 00:16:24.075927: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 00:16:24.110042: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-06 00:16:24.110117: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-06 00:16:24.110142: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-06 00:16:24.116651: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 00:16:24.116917: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-06 00:16:24.799618: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=2
# Loading logs/6_e/rlzoo3/ppo/Reacher-v4_2/Reacher-v4.zip
# Loading running average
# with params: {'norm_obs': True, 'norm_reward': False}
# Episode Reward: -5.84
# Episode Length 50
# Episode Reward: -4.39
# Episode Length 50
# Episode Reward: -5.43
# Episode Length 50
# Episode Reward: -1.77
# Episode Length 50
# Episode Reward: -4.80
# Episode Length 50
# Episode Reward: -6.89
# Episode Length 50
# Episode Reward: -7.60
# Episode Length 50
# Episode Reward: -4.83
# Episode Length 50
# Episode Reward: -6.61
# Episode Length 50
# Episode Reward: -8.45
# Episode Length 50
# Episode Reward: -11.10
# Episode Length 50
# Episode Reward: -8.26
# Episode Length 50
# Episode Reward: -7.80
# Episode Length 50
# Episode Reward: -14.50
# Episode Length 50
# Episode Reward: -8.59
# Episode Length 50
# Episode Reward: -7.88
# Episode Length 50
# Episode Reward: -12.81
# Episode Length 50
# Episode Reward: -7.56
# Episode Length 50
# Episode Reward: -6.31
# Episode Length 50
# Episode Reward: -11.81
# Episode Length 50
# Episode Reward: -5.63
# Episode Length 50
# Episode Reward: -17.99
# Episode Length 50
# Episode Reward: -5.15
# Episode Length 50
# Episode Reward: -9.79
# Episode Length 50
# Episode Reward: -10.86
# Episode Length 50
# Episode Reward: -3.71
# Episode Length 50
# Episode Reward: -7.91
# Episode Length 50
# Episode Reward: -6.22
# Episode Length 50
# Episode Reward: -11.62
# Episode Length 50
# Episode Reward: -8.86
# Episode Length 50
# Episode Reward: -8.45
# Episode Length 50
# Episode Reward: -5.33
# Episode Length 50
# Episode Reward: -5.49
# Episode Length 50
# Episode Reward: -6.28
# Episode Length 50
# Episode Reward: -9.20
# Episode Length 50
# Episode Reward: -7.48
# Episode Length 50
# Episode Reward: -6.40
# Episode Length 50
# Episode Reward: -8.83
# Episode Length 50
# Episode Reward: -7.11
# Episode Length 50
# Episode Reward: -5.76
# Episode Length 50
# Episode Reward: -6.90
# Episode Length 50
# Episode Reward: -10.36
# Episode Length 50
# Episode Reward: -2.07
# Episode Length 50
# Episode Reward: -9.74
# Episode Length 50
# Episode Reward: -3.89
# Episode Length 50
# Episode Reward: -8.41
# Episode Length 50
# Episode Reward: -8.54
# Episode Length 50
# Episode Reward: -8.25
# Episode Length 50
# Episode Reward: -12.62
# Episode Length 50
# Episode Reward: -4.31
# Episode Length 50
# Episode Reward: -7.33
# Episode Length 50
# Episode Reward: -7.45
# Episode Length 50
# Episode Reward: -9.96
# Episode Length 50
# Episode Reward: -8.74
# Episode Length 50
# Episode Reward: -17.38
# Episode Length 50
# Episode Reward: -3.60
# Episode Length 50
# Episode Reward: -5.83
# Episode Length 50
# Episode Reward: -13.58
# Episode Length 50
# Episode Reward: -12.83
# Episode Length 50
# Episode Reward: -8.70
# Episode Length 50
# Episode Reward: -6.02
# Episode Length 50
# Episode Reward: -11.10
# Episode Length 50
# Episode Reward: -11.98
# Episode Length 50
# Episode Reward: -6.32
# Episode Length 50
# Episode Reward: -4.55
# Episode Length 50
# Episode Reward: -2.91
# Episode Length 50
# Episode Reward: -7.53
# Episode Length 50
# Episode Reward: -7.51
# Episode Length 50
# Episode Reward: -8.88
# Episode Length 50
# Episode Reward: -8.97
# Episode Length 50
# Episode Reward: -3.43
# Episode Length 50
# Episode Reward: -6.71
# Episode Length 50
# Episode Reward: -5.48
# Episode Length 50
# Episode Reward: -9.79
# Episode Length 50
# Episode Reward: -5.77
# Episode Length 50
# Episode Reward: -8.11
# Episode Length 50
# Episode Reward: -8.66
# Episode Length 50
# Episode Reward: -5.90
# Episode Length 50
# Episode Reward: -9.00
# Episode Length 50
# Episode Reward: -7.61
# Episode Length 50
# Episode Reward: -6.10
# Episode Length 50
# Episode Reward: -6.28
# Episode Length 50
# Episode Reward: -8.48
# Episode Length 50
# Episode Reward: -7.52
# Episode Length 50
# Episode Reward: -5.68
# Episode Length 50
# Episode Reward: -7.30
# Episode Length 50
# Episode Reward: -8.37
# Episode Length 50
# Episode Reward: -7.42
# Episode Length 50
# Episode Reward: -5.79
# Episode Length 50
# Episode Reward: -7.72
# Episode Length 50
# Episode Reward: -5.41
# Episode Length 50
# Episode Reward: -7.99
# Episode Length 50
# Episode Reward: -6.27
# Episode Length 50
# Episode Reward: -5.95
# Episode Length 50
# Episode Reward: -11.15
# Episode Length 50
# Episode Reward: -6.49
# Episode Length 50
# Episode Reward: -9.78
# Episode Length 50
# Episode Reward: -6.86
# Episode Length 50
# Episode Reward: -5.58
# Episode Length 50
# Episode Reward: -7.07
# Episode Length 50
# 100 Episodes
# Mean reward: -7.71 +/- 2.83
# Mean episode length: 50.00 +/- 0.00

# %% [markdown]
# #### Record Video and play back

# %%
# !python -m rl_zoo3.record_video --algo ppo --env Reacher-v4 --exp-id 0 -f logs/6_d/rlzoo3/ -n 1000
# Out:
# 2023-11-06 01:23:28.354226: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-06 01:23:28.356701: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 01:23:28.395988: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-06 01:23:28.396072: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-06 01:23:28.396103: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-06 01:23:28.404204: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 01:23:28.404510: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-06 01:23:29.582817: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/6_e/rlzoo3/ppo/Reacher-v4_1/Reacher-v4.zip
# Loading logs/6_e/rlzoo3/ppo/Reacher-v4_1/Reacher-v4.zip
# Saving video to /home/nsanghi/sandbox/apress/drl-2ed/chapter6/logs/6_e/rlzoo3/ppo/Reacher-v4_1/videos/final-model-ppo-Reacher-v4-step-0-to-step-1000.mp4
# Moviepy - Building video /home/nsanghi/sandbox/apress/drl-2ed/chapter6/logs/6_e/rlzoo3/ppo/Reacher-v4_1/videos/final-model-ppo-Reacher-v4-step-0-to-step-1000.mp4.
# Moviepy - Writing video /home/nsanghi/sandbox/apress/drl-2ed/chapter6/logs/6_e/rlzoo3/ppo/Reacher-v4_1/videos/final-model-ppo-Reacher-v4-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /home/nsanghi/sandbox/apress/drl-2ed/chapter6/logs/6_e/rlzoo3/ppo/Reacher-v4_1/videos/final-model-ppo-Reacher-v4-step-0-to-step-1000.mp4

# %%
video_file_rlzoo = "logs/6_d/rlzoo3/ppo/Reacher-v4_1/videos/final-model-ppo-Reacher-v4-step-0-to-step-1000.mp4"
play_video(video_file_rlzoo)
# Out:
#         <video width=400 controls>
#               <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %% [markdown]
# #### Train Agent with TRPO, a different Algorithm

# %%
# !python -m rl_zoo3.train --algo trpo --env ReacherBulletEnv-v0 --progress \
--log-interval 400 --save-freq 10000 --eval-freq 10000 --eval-episodes 10 \
--n-timesteps 100000 \
--track --wandb-project-name trpo-ReacherBulletEnv-v0 -f logs/6_d/rlzoo3/
# Out:
# 2023-11-06 01:34:40.589819: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-06 01:34:40.592202: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 01:34:40.628660: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-06 01:34:40.628737: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-06 01:34:40.628762: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-06 01:34:40.636171: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 01:34:40.636433: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-06 01:34:41.331144: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ========== ReacherBulletEnv-v0 ==========
# Seed: 2138361651
# wandb: Currently logged in as: nsanghi. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in /home/nsanghi/sandbox/apress/drl-2ed/chapter6/wandb/run-20231106_013445-spchp2lq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ReacherBulletEnv-v0__trpo__2138361651__1699214684
# wandb: ⭐️ View project at https://wandb.ai/nsanghi/trpo-ReacherBulletEnv-v0
# wandb: 🚀 View run at https://wandb.ai/nsanghi/trpo-ReacherBulletEnv-v0/runs/spchp2lq
# Loading hyperparameters from: /home/nsanghi/sandbox/apress/drl-2ed/venv39/lib/python3.9/site-packages/rl_zoo3/hyperparams/trpo.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 128),
#              ('cg_damping', 0.1),
#              ('cg_max_steps', 25),
#              ('gae_lambda', 0.95),
#              ('gamma', 0.99),
#              ('learning_rate', 0.001),
#              ('n_critic_updates', 20),
#              ('n_envs', 2),
#              ('n_steps', 1024),
#              ('n_timesteps', 300000.0),
#              ('normalize', True),
#              ('policy', 'MlpPolicy'),
#              ('policy_kwargs',
#               'dict(log_std_init=-1, ortho_init=False, activation_fn=nn.ReLU, '
#               'net_arch=dict(pi=[256, 256], vf=[256, 256]) )'),
#              ('sub_sampling_factor', 1)])
# Using 2 environments
# Overwriting n_timesteps with n=100000
# Creating test environment
# pybullet build time: May 20 2022 19:45:31
# /home/nsanghi/sandbox/apress/drl-2ed/venv39/lib/python3.9/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Normalization activated: {'gamma': 0.99, 'norm_reward': False, 'training': False}
# Normalization activated: {'gamma': 0.99}
# Using cpu device
# Log path: logs/6_e/rlzoo3//trpo/ReacherBulletEnv-v0_1
# argv[0]=
# argv[0]=
# /home/nsanghi/sandbox/apress/drl-2ed/venv39/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:141: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /home/nsanghi/sandbox/apress/drl-2ed/venv39/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# argv[0]=
# argv[0]=
# Logging to runs/ReacherBulletEnv-v0__trpo__2138361651__1699214684/ReacherBulletEnv-v0/TRPO_1
# /home/nsanghi/sandbox/apress/drl-2ed/venv39/lib/python3.9/site-packages/gym/util0:00:00 < -:--:-- , ? it/s ]
# s/passive_env_checker.py:141: UserWarning: WARN: The obs returned by the
# `step()` method was expecting numpy array dtype to be float32, actual type:
# float64
#   logger.warn(
# /home/nsanghi/sandbox/apress/drl-2ed/venv39/lib/python3.9/site-packages/gym/util0:00:00 < -:--:-- , ? it/s ]
# s/passive_env_checker.py:165: UserWarning: WARN: The obs returned by the
# `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
#   10% ━━╸━━━━━━━━━━━━━━━━━━━━━━━ 9,966/100,000  [ 0:00:23 < 0:03:34 , 421 it/s ]argv[0]=
# argv[0]=
# Eval num_timesteps=10000, episode_reward=-0.69 +/- 12.03━━━━━━━━ 9,966/100,000  [ 0:00:25 < 0:03:34 , 421 it/s ]
# Episode length: 150.00 +/- 0.00m━━━━━━━━━━━━━━━━━━━━━━━ 9,966/100,000  [ 0:00:25 < 0:03:34 , 421 it/s ]
# ----------------------------------------━━━━━━━━━━━━━━━━━━━━ 9,966/100,000  [ 0:00:25 < 0:03:34 , 421 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | -0.687   |
# | time/                     |          |
# |    total_timesteps        | 10000    |
# | train/                    |          |
# |    explained_variance     | 0.865    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00406  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 4        |
# |    policy_objective       | 0.0417   |
# |    std                    | 0.368    |
# |    value_loss             | 0.0121   |
# ----------------------------------------
# New best mean reward!m╸━━━━━━━━━━━━━━━━━━━━━━━ 9,966/100,000  [ 0:00:25 < 0:03:34 , 421 it/s ]
# Eval num_timesteps=20000, episode_reward=-3.31 +/- 14.04━━━━━━━ 19,910/100,000  [ 0:00:55 < 0:03:49 , 350 it/s ]
# Episode length: 150.00 +/- 0.00━━━━━━━━━━━━━━━━━━━━ 19,910/100,000  [ 0:00:55 < 0:03:49 , 350 it/s ]
# ----------------------------------------━━━━━━━━━━━━━━━━━━━ 19,910/100,000  [ 0:00:55 < 0:03:49 , 350 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | -3.31    |
# | time/                     |          |
# |    total_timesteps        | 20000    |
# | train/                    |          |
# |    explained_variance     | 0.958    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00497  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 9        |
# |    policy_objective       | 0.0531   |
# |    std                    | 0.353    |
# |    value_loss             | 0.00425  |
# ----------------------------------------
# Eval num_timesteps=30000, episode_reward=3.63 +/- 14.77━━━━━━━━ 29,912/100,000  [ 0:01:25 < 0:03:26 , 341 it/s ]
# Episode length: 150.00 +/- 0.00m╺━━━━━━━━━━━━━━━━━ 29,912/100,000  [ 0:01:25 < 0:03:26 , 341 it/s ]
# ----------------------------------------0m━━━━━━━━━━━━━━━━━ 29,912/100,000  [ 0:01:25 < 0:03:26 , 341 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | 3.63     |
# | time/                     |          |
# |    total_timesteps        | 30000    |
# | train/                    |          |
# |    explained_variance     | 0.961    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00476  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 14       |
# |    policy_objective       | 0.0474   |
# |    std                    | 0.34     |
# |    value_loss             | 0.00315  |
# ----------------------------------------
# New best mean reward!━━╺━━━━━━━━━━━━━━━━━ 29,912/100,000  [ 0:01:25 < 0:03:26 , 341 it/s ]
# Eval num_timesteps=40000, episode_reward=3.58 +/- 11.52━━━━━━━━ 39,992/100,000  [ 0:02:00 < 0:02:55 , 345 it/s ]
# Episode length: 150.00 +/- 0.0091m╸━━━━━━━━━━━━━━━ 39,992/100,000  [ 0:02:00 < 0:02:55 , 345 it/s ]
# ----------------------------------------━━━━━━━━━━━━━━━ 39,992/100,000  [ 0:02:00 < 0:02:55 , 345 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | 3.58     |
# | time/                     |          |
# |    total_timesteps        | 40000    |
# | train/                    |          |
# |    explained_variance     | 0.947    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00467  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 19       |
# |    policy_objective       | 0.0469   |
# |    std                    | 0.332    |
# |    value_loss             | 0.00313  |
# ----------------------------------------
# Eval num_timesteps=50000, episode_reward=2.54 +/- 7.19━━━━━━━━━ 49,904/100,000  [ 0:02:31 < 0:02:27 , 342 it/s ]
# Episode length: 150.00 +/- 0.00m╺━━━━━━━━━━━━ 49,904/100,000  [ 0:02:31 < 0:02:27 , 342 it/s ]
# ----------------------------------------0m━━━━━━━━━━━━ 49,904/100,000  [ 0:02:31 < 0:02:27 , 342 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | 2.54     |
# | time/                     |          |
# |    total_timesteps        | 50000    |
# | train/                    |          |
# |    explained_variance     | 0.972    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00481  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 24       |
# |    policy_objective       | 0.0515   |
# |    std                    | 0.329    |
# |    value_loss             | 0.00237  |
# ----------------------------------------
# Eval num_timesteps=60000, episode_reward=8.26 +/- 15.32━━━━━━━━ 59,954/100,000  [ 0:03:04 < 0:02:00 , 336 it/s ]
# Episode length: 150.00 +/- 0.00╸━━━━━━━━━━ 59,954/100,000  [ 0:03:04 < 0:02:00 , 336 it/s ]
# ----------------------------------------━━━━━━━━━━ 59,954/100,000  [ 0:03:04 < 0:02:00 , 336 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | 8.26     |
# | time/                     |          |
# |    total_timesteps        | 60000    |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00406  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 29       |
# |    policy_objective       | 0.0453   |
# |    std                    | 0.324    |
# |    value_loss             | 0.00165  |
# ----------------------------------------
# New best mean reward!━━━━━━━━━╸━━━━━━━━━━ 59,954/100,000  [ 0:03:04 < 0:02:00 , 336 it/s ]
# Eval num_timesteps=70000, episode_reward=10.99 +/- 13.24━━━━━━━ 69,942/100,000  [ 0:03:40 < 0:01:39 , 305 it/s ]
# Episode length: 150.00 +/- 0.00━━╺━━━━━━━ 69,942/100,000  [ 0:03:40 < 0:01:39 , 305 it/s ]
# ----------------------------------------0m╺━━━━━━━ 69,942/100,000  [ 0:03:40 < 0:01:39 , 305 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | 11       |
# | time/                     |          |
# |    total_timesteps        | 70000    |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00602  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 34       |
# |    policy_objective       | 0.0549   |
# |    std                    | 0.319    |
# |    value_loss             | 0.00268  |
# ----------------------------------------
# New best mean reward!━━━━━━━━━━━━╺━━━━━━━ 69,942/100,000  [ 0:03:40 < 0:01:39 , 305 it/s ]
# Eval num_timesteps=80000, episode_reward=10.52 +/- 9.8990m━━━━━ 79,956/100,000  [ 0:04:16 < 0:01:07 , 302 it/s ]
# Episode length: 150.00 +/- 0.00━━━━╸━━━━━ 79,956/100,000  [ 0:04:16 < 0:01:07 , 302 it/s ]
# ----------------------------------------╸━━━━━ 79,956/100,000  [ 0:04:16 < 0:01:07 , 302 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | 10.5     |
# | time/                     |          |
# |    total_timesteps        | 80000    |
# | train/                    |          |
# |    explained_variance     | 0.97     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00434  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 39       |
# |    policy_objective       | 0.0537   |
# |    std                    | 0.316    |
# |    value_loss             | 0.00159  |
# ----------------------------------------
# Eval num_timesteps=90000, episode_reward=13.14 +/- 13.20━━ 89,898/100,000  [ 0:04:47 < 0:00:30 , 340 it/s ]
# Episode length: 150.00 +/- 0.00━━━━━━━╺━━ 89,898/100,000  [ 0:04:47 < 0:00:30 , 340 it/s ]
# ----------------------------------------0m╺━━ 89,898/100,000  [ 0:04:47 < 0:00:30 , 340 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | 13.1     |
# | time/                     |          |
# |    total_timesteps        | 90000    |
# | train/                    |          |
# |    explained_variance     | 0.976    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00468  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 43       |
# |    policy_objective       | 0.0678   |
# |    std                    | 0.31     |
# |    value_loss             | 0.0016   |
# ----------------------------------------
# New best mean reward!━━━━━━━━━━━━━━━━━╺━━ 89,898/100,000  [ 0:04:47 < 0:00:30 , 340 it/s ]
# Eval num_timesteps=100000, episode_reward=12.93 +/- 11.57m 99,860/100,000  [ 0:05:21 < 0:00:01 , 348 it/s ]t/s ]
# Episode length: 150.00 +/- 0.00━━━━━━━━━╸ 99,860/100,000  [ 0:05:21 < 0:00:01 , 348 it/s ]
# ----------------------------------------╸ 99,860/100,000  [ 0:05:21 < 0:00:01 , 348 it/s ]
# | eval/                     |          |
# |    mean_ep_length         | 150      |
# |    mean_reward            | 12.9     |
# | time/                     |          |
# |    total_timesteps        | 100000   |
# | train/                    |          |
# |    explained_variance     | 0.98     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00437  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 48       |
# |    policy_objective       | 0.044    |
# |    std                    | 0.297    |
# |    value_loss             | 0.00106  |
# ----------------------------------------
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━ 100,352/100,000  [ 0:05:21 < 0:00:00 , 290 it/s ]t/s ]
# Saving to logs/6_e/rlzoo3//trpo/ReacherBulletEnv-v0_1
